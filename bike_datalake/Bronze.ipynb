# %% [markdown]
# #Reading from CSV file

# %%
df = (
    spark.read.option("header", "true").option("inferSchema", "true").csv("/Volumes/workspace/bronze/source_systems/source_crm/sales_details.csv")
)
df.display()

# %%
df = (
    spark.read.option("header", "true").option("inferSchema", "true").csv("/Volumes/workspace/bronze/source_systems/source_crm/cust_info.csv")
)
df.display()

# %%
df = (
    spark.read.option("header", "true").option("inferSchema", "true").csv("/Volumes/workspace/bronze/source_systems/source_crm/prd_info.csv")
)
df.display()

# %%
df = (
    spark.read.option("header", "true").option("inferSchema", "true").csv("/Volumes/workspace/bronze/source_systems/source_erp/CUST_AZ12.csv")
)
df.display()

# %%
df = (
    spark.read.option("header", "true").option("inferSchema", "true").csv("/Volumes/workspace/bronze/source_systems/source_erp/LOC_A101.csv")
)
df.display()

# %%
df = (
    spark.read.option("header", "true").option("inferSchema", "true").csv("/Volumes/workspace/bronze/source_systems/source_erp/PX_CAT_G1V2.csv")
)
df.display()

# %% [markdown]
# #Write it to Bronze Layer

# %%
df.write.mode("overwrite").saveAsTable("workspace.bronze.crm_sales_details")

# %%
# %sql

select * from workspace.bronze.crm_sales_details

# %%
df.write.mode("overwrite").saveAsTable("workspace.bronze.crm_prd_info")

# %%
# %sql

select * from workspace.bronze.crm_prd_info

# %%
df.write.mode("overwrite").saveAsTable("workspace.bronze.crm_cust_info")

# %%
# %sql

select * from workspace.bronze.crm_cust_info

# %%
df.write.mode("overwrite").saveAsTable("workspace.bronze.erp_cust")

# %%
df.write.mode("overwrite").saveAsTable("workspace.bronze.erp_loc")

# %%
df.write.mode("overwrite").saveAsTable("workspace.bronze.erp_px_cat")

# %%
# %sql

select * from workspace.bronze.erp_cust

# %%
# %sql

select * from workspace.bronze.erp_loc

# %%
# %sql

select * from workspace.bronze.erp_px_cat
